# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

import matplotlib.colors as colors
import matplotlib.cm as cm

import matplotlib.image as mpimg

# from heat.heat import Heat
#from heat.plot import Plot

# import src.heat, src.plot
import .heat, .plot

# from heat import Heat
# from plot import Plot


# read data
df = pd.read_csv('/Users/lukasgehrke/Documents/temp/chatham/crd_gaze_phys-LOW_work-HIGH_equip-Bike_all_good_s.csv')
# df = pd.read_csv('/Users/lukasgehrke/Documents/temp/chatham/crd_gaze_phys-LOW_work-HIGH_equip-Treadmill_all_good_s.csv')

# df = pd.read_csv('/Users/lukasgehrke/Documents/temp/chatham/crd_gaze_phys-HIGH_work-HIGH_equip-Bike_all_good_s.csv')
# df = pd.read_csv('/Users/lukasgehrke/Documents/temp/chatham/crd_gaze_phys-HIGH_work-HIGH_equip-Treadmill_all_good_s.csv')

s = df[df['pID'] == 23]
s = s[['X', 'Y']]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
hist, xedges, yedges = np.histogram2d(s.X, s.Y, bins=50)

# Construct arrays for the anchor positions of the 16 bars.
xpos, ypos = np.meshgrid(xedges[:-1] + 0.25, yedges[:-1] + 0.25, indexing="ij")
xpos = xpos.ravel()
ypos = ypos.ravel()
zpos = 0

# Construct arrays with the dimensions for the 16 bars.
dx = dy = 30 * np.ones_like(zpos)
dz = hist.ravel()

offset = dz + np.abs(dz.min())
fracs = offset.astype(float)/offset.max()
norm = colors.Normalize(fracs.min(), fracs.max())
color_values = cm.jet(norm(fracs.tolist()))

ax.bar3d(xpos, ypos, zpos, dx, dy, dz, color=color_values, zsort='average')

plt.show()

# # for subject in range(23, 48):

#     # select a subject
#     # this_s = df[df['pID'] == subject]

# # img = mpimg.imread('/Users/lukasgehrke/Documents/temp/matb.png') # read background image for heatmap
# # h = src.heat.Heat('workhigh', df, None, img) # create heatmap

# # specify resolution
# # bins = [np.linspace(0, 1280, 100), np.linspace(0, 720, 100)]

# # do binning on pandas dataframe with cut()
# bins_x = np.linspace(0, 1280, 100)
# # bins_y = np.linspace(0, 720, 100)
# groups = s.groupby(pd.cut(s.X, bins_x))

# # binned = s.groupby([pd.cut(s.X, np.linspace(0, 1280, 100)), pd.cut(s.Y, np.linspace(0, 720, 100))]).mean().unstack()

# hist = np.histogram2d(s.X, s.Y, bins= 100)

# # and plot
# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')

# # prepare 3d bar plot
# top = hist[1] + hist[2]
# bottom = np.zeros_like(top)
# width = depth = 1

# # colormap
# dz = hist[0]
# offset = dz + np.abs(dz.min())
# fracs = offset.astype(float)/offset.max()
# norm = colors.Normalize(fracs.min(), fracs.max())
# color_values = cm.jet(norm(fracs.tolist()))
# ax.bar3d(hist[1],hist[2],hist[0],1,1,dz, color=color_values)

# # and plot
# fig = plt.figure()
# ax1 = fig.add_subplot(111, projection='3d')
# ax1.bar3d(s.X, s.Y, bottom, width, depth, top, shade=True)
# ax1.set_title('Shaded')
# plt.show()

# h.heatmap, xedges, yedges = h.histogram2d(bins)
# h.heatmap = h.zscore(h.heatmap)
# h.heatmap = h.gaussian(h.heatmap, 2)
# h.heatmap = h.heatmap.T

# # create plot and draw
# p = plot.Plot(h)
# p.cm = p.make_cm_transparent(p.cm)
# p.heat_xy(title="Gaze Heatmap Treadmill, grand-average High work, Low phys", lims=[0,4], superimpose_on_bg=True)
# Out:
# Error: Direct kernel connection broken
# at f.getDisposedError (/Users/lukasgehrke/.vscode/extensions/ms-python.python-2020.7.94776/out/client/extension.js:24:542513)
# at f.P.handleCodeRequest (/Users/lukasgehrke/.vscode/extensions/ms-python.python-2020.7.94776/out/client/extension.js:48:455592)
# at /Users/lukasgehrke/.vscode/extensions/ms-python.python-2020.7.94776/out/client/extension.js:48:468051
# at processTicksAndRejections (internal/process/task_queues.js:85:5)
